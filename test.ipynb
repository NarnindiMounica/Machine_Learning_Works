# %%
import pandas as pd
import json

a = {"a": [1,2,3], "b":[3,4,5], "c":[6,7,8]}
df = pd.DataFrame(a)
list(json.loads(df.T.to_json()).values())
# Out:
# [{'a': 1, 'b': 3, 'c': 6}, {'a': 2, 'b': 4, 'c': 7}, {'a': 3, 'b': 5, 'c': 8}]
