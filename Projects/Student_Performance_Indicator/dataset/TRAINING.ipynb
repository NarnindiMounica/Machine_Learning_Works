# %% [markdown]
# ### Student Performance Indicator - Model Training

# %%
#importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import RandomizedSearchCV

from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor

# %%
#importing dataset as dataframe

df = pd.read_csv("stud.csv")
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#preparing independent and dependent variables

x = df.drop('math_score', axis=1)
y = df['math_score']

# %%
#getting categorical and numerical features

num_columns = [col for col in x.columns if x[col].dtype != "str"]
cat_columns = [col for col in x.columns if x[col].dtype == "str"]

# %%
#splitting data into train, test sets

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
#preprocessing data

one_hot_obj = OneHotEncoder(drop="first")
scaler_obj = StandardScaler()

preprocessor = ColumnTransformer([
    ("one_hot_encoding", one_hot_obj, cat_columns),
    ("standard_scaler", scaler_obj, num_columns)
], remainder="passthrough")

# %%
x_train = preprocessor.fit_transform(x_train)
x_test = preprocessor.transform(x_test)

# %%
#evalution function

def evaluation_results(y_test, y_pred):
    r2_value = r2_score(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    return (r2_value, mse, mae)

# %%
models = {"Linear Regression": LinearRegression(),
          "Ridge": Ridge(),
          "Lasso": Lasso(),
          "Support Vector Regressor": SVR(),
          "KNN": KNeighborsRegressor(),
          "Decision Tree": DecisionTreeRegressor(),
          "Random Forest": RandomForestRegressor(),
          "Adaptive Boosting": AdaBoostRegressor(),
          "Cat Boosting": CatBoostRegressor(),
          "XG Boosting": XGBRegressor()}

train_performance_metrics = []
test_performance_metrics = []

for item in range(len(models.keys())):
    model_objs = list(models.values())
    model = model_objs[item]

    #model training
    model.fit(x_train, y_train)

    #model prediction 
    y_pred_train = model.predict(x_train)
    y_pred_test = model.predict(x_test)

    #performance metrics evalution
    train_performance_metrics.append(evaluation_results(y_train, y_pred_train))
    test_performance_metrics.append(evaluation_results(y_test, y_pred_test))

met_train=pd.DataFrame(data=train_performance_metrics, columns=['Train R_Square', 'Train MSE', 'Train MAE'], index=models.keys())
met_test=pd.DataFrame(data=test_performance_metrics, columns=['Test R_Square', 'Test MSE', 'Test MAE'], index=models.keys())
met = pd.concat([met_train, met_test], axis=1)
met
# Out:
# Learning rate set to 0.039525
# 0:	learn: 14.6182162	total: 759us	remaining: 759ms
# 1:	learn: 14.2679232	total: 1.16ms	remaining: 580ms
# 2:	learn: 13.9259502	total: 1.67ms	remaining: 557ms
# 3:	learn: 13.5925455	total: 2.19ms	remaining: 546ms
# 4:	learn: 13.2881685	total: 2.65ms	remaining: 528ms
# 5:	learn: 12.9738597	total: 3.2ms	remaining: 530ms
# 6:	learn: 12.6794798	total: 3.65ms	remaining: 517ms
# 7:	learn: 12.3815862	total: 4.07ms	remaining: 505ms
# 8:	learn: 12.0744423	total: 4.49ms	remaining: 495ms
# 9:	learn: 11.7821385	total: 5.02ms	remaining: 497ms
# 10:	learn: 11.5327154	total: 5.46ms	remaining: 491ms
# 11:	learn: 11.2696189	total: 5.87ms	remaining: 483ms
# 12:	learn: 11.0112102	total: 6.29ms	remaining: 478ms
# 13:	learn: 10.7949384	total: 6.73ms	remaining: 474ms
# 14:	learn: 10.5691504	total: 7.69ms	remaining: 505ms
# 15:	learn: 10.3395526	total: 8.19ms	remaining: 504ms
# 16:	learn: 10.1180379	total: 8.71ms	remaining: 504ms
# ...

# %% [markdown]
# Linear Regression model is performing better on this dataset.
